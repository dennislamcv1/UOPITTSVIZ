# %%
#Preamble code

import seaborn as sns

# %%
#Skeleton code
#Learners will complete this code
#Task: Modify the following code to create a histogram of the amount of the bill, stacked for dinner vs lunch represented by different color

# Apply the default theme
sns.set_theme()

# %%
# Load an example dataset
# your code goes here
tips = sns.load_dataset("tips")

# %%
# Create a visualization
# your code goes here
sns.histplot(data=tips,x="bill",hue="time",multiple="stack")
